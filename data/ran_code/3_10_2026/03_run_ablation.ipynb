# %% [markdown]
# # Retrieval Head Ablation (Step 2)

# %% [markdown]
# ### Validate identified retrieval heads via targeted ablation on held-out data

# %%
# %pip install torch transformers numpy huggingface_hub accelerate bitsandbytes python-dotenv pandas scikit-learn
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (2.10.0+cu128)
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (5.0.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (2.0.2)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.12/dist-packages (1.5.0)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.12/dist-packages (1.13.0)
# Collecting bitsandbytes
#   Downloading bitsandbytes-0.49.2-py3-none-manylinux_2_24_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.12/dist-packages (1.2.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (1.6.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch) (3.25.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch) (2025.3.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch) (1.4.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (26.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.22.2)
# Requirement already satisfied: typer-slim in /usr/local/lib/python3.12/dist-packages (from transformers) (0.24.0)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers) (4.67.3)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (1.3.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (0.28.1)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (0.24.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.3)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub) (4.12.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface_hub) (0.16.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch) (3.0.3)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface_hub) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface_hub) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface_hub) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface_hub) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface_hub) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface_hub) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->huggingface_hub) (0.1.2)
# Downloading bitsandbytes-0.49.2-py3-none-manylinux_2_24_x86_64.whl (60.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.7/60.7 MB 44.3 MB/s eta 0:00:00
# Installing collected packages: bitsandbytes
# Successfully installed bitsandbytes-0.49.2

# %%
import os
import re
import json
import random
import torch
import numpy as np
import pandas as pd
from contextlib import nullcontext
from collections import Counter
from transformers import AutoTokenizer, AutoModelForCausalLM
from huggingface_hub import login
from dotenv import load_dotenv

# %% [markdown]
# #### If using Google Colab: Run The Following Cells (Ignore if using some other environment)

# %%
from google.colab import userdata

HF_TOKEN = userdata.get('HF_TOKEN')

# %%
if HF_TOKEN:
    login(token=HF_TOKEN)
    print("HF_TOKEN loaded and Hugging Face login successful.")
else:
    print("HF_TOKEN not found.")
# Out:
# HF_TOKEN loaded and Hugging Face login successful.

# %% [markdown]
# #### If using a high end GPU not from Colab, but from Lambda Labs

# %%
load_dotenv(override=False)

HF_TOKEN = os.getenv("HF_TOKEN") or globals().get("HF_TOKEN")

if HF_TOKEN:
    os.environ["HF_TOKEN"] = HF_TOKEN
    login(token=HF_TOKEN)
    print("HF_TOKEN loaded and Hugging Face login successful.")
else:
    print("HF_TOKEN not found. Add HF_TOKEN=... to your .env file or set it in the environment.")

# %% [markdown]
# #### Configuration & Hyperparameters

# %%
MODEL_ID = "meta-llama/Meta-Llama-3-8B-Instruct"

TARGET_SEQ_LEN = 7000
NEEDLE_DEPTH = 0.5
SPLIT = 0.8
SPLIT_SEED = 42

TASKS = [
    {"id": "registrant_name", "question": "What is the registrant's name?"},
    {"id": "headquarters_city", "question": "What is the registrant's headquarters city?"},
    {"id": "headquarters_state", "question": "What is the registrant's headquarters state?"},
    {"id": "incorporation_state", "question": "What is the registrant's incorporation state?"},
    {"id": "incorporation_year", "question": "What is the incorporation year?"},
    {"id": "employees_count_total", "question": "How many total employees does the registrant have?"},
    {"id": "holder_record_amount", "question": "What is the number of holders of record of the registrant's common stock?"},
    {"id": "employees_count_full_time", "question": "How many full-time employees does the registrant have?"},
    {"id": "ceo_lastname", "question": "What is the CEO's last name?"},
]
TASK_MAP = {t["id"]: t for t in TASKS}

# Paths
DATA_PATH = "/content/cleaned_EDGAR_gt_2-22-2026.csv"

RANKING_RUN_NAME = "/content/rank_2026-03-10_19-23-13" # Update this to your ranking run
HEADS_JSON_PATH = f"{RANKING_RUN_NAME}/ranked_heads.json"

import datetime
TIMESTAMP = datetime.datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
ABLATION_OUTPUT_DIR = f"/content/ablation_{TIMESTAMP}"

# Ablation-specific config
ABLATION_K_VALUES = [1, 2, 5, 10, 20, 32, 64, 96, 128]
MAX_DECODE_TOKENS = 20

# Model loading
TORCH_DTYPE = torch.bfloat16
ATTN_IMPL = "eager"

print("Configuration loaded.")
print(f"Model: {MODEL_ID}")
print(f"Ablation K values: {ABLATION_K_VALUES}")
print(f"Max decode tokens: {MAX_DECODE_TOKENS}")
print(f"Heads JSON: {HEADS_JSON_PATH}")
# Out:
# Configuration loaded.
# Model: meta-llama/Meta-Llama-3-8B-Instruct
# Ablation K values: [1, 2, 5, 10, 20, 32, 64, 96, 128]
# Max decode tokens: 20
# Heads JSON: /content/rank_2026-03-10_19-23-13/ranked_heads.json

# %%
# If the right meta.json attributes are present, feel free to run this validation code to make sure this experiment will be consistent with the data you have
parent_directory = os.path.dirname(HEADS_JSON_PATH)
print(parent_directory)
with open("/content/rank_2026-03-10_19-23-13/meta.json", "r") as f:
    rank_heads_meta = json.load(f)
SOURCE_MODEL = rank_heads_meta.get("source_model")
TOP_K_HEADS = rank_heads_meta.get("top_k_heads")

if SOURCE_MODEL != MODEL_ID:
    print("WARNING:")
    print(f"SOURCE_MODEL from this data and current MODEL_ID differ\nSOURCE_MODEL: {SOURCE_MODEL} != MODEL_ID: {MODEL_ID}")

if ABLATION_K_VALUES[-1] != TOP_K_HEADS:
    print("WARNING:")
    print(f"Top K Heads from this data and current Max Number Of Ablations differ\nTop K Heads: {TOP_K_HEADS} != Max Number Of Ablations: {ABLATION_K_VALUES[-1]}")
# Out:
# /content/rank_2026-03-10_19-23-13

# %% [markdown]
# ##### Tokenizer & Model Loading

# %%
tokenizer = AutoTokenizer.from_pretrained(MODEL_ID, token=HF_TOKEN)

if tokenizer.pad_token is None:
    tokenizer.pad_token = tokenizer.eos_token

print(f"Tokenizer loaded: {MODEL_ID}")
print(f"Vocab size: {tokenizer.vocab_size:,}")
# Out:
# config.json:   0%|          | 0.00/654 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/73.0 [00:00<?, ?B/s]
# Tokenizer loaded: meta-llama/Meta-Llama-3-8B-Instruct
# Vocab size: 128,000

# %%
model = AutoModelForCausalLM.from_pretrained(
    MODEL_ID,
    token=HF_TOKEN,
    torch_dtype=TORCH_DTYPE,
    device_map="auto",
    attn_implementation=ATTN_IMPL,
)
model.eval()

print(f"Model loaded: {MODEL_ID}")
print(f"dtype: {next(model.parameters()).dtype}")
print(f"Num layers: {model.config.num_hidden_layers}")
print(f"Num heads (Q): {model.config.num_attention_heads}")
print(f"Num KV heads: {model.config.num_key_value_heads}")
# Out:
# `torch_dtype` is deprecated! Use `dtype` instead!
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 4 files:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/291 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/187 [00:00<?, ?B/s]
# Model loaded: meta-llama/Meta-Llama-3-8B-Instruct
# dtype: torch.bfloat16
# Num layers: 32
# Num heads (Q): 32
# Num KV heads: 8

# %%
# Quick change in ablation numbers to match ananya's

ABLATION_K_VALUES = [8, 16, 32, 48, 64, 96, 128]

# %% [markdown]
# ---
# ## Section 2 -- Load Ablation Split & Identified Heads

# %%
from sklearn.model_selection import train_test_split

df = pd.read_csv(DATA_PATH)
df = df[df["haystack_token_length"] == TARGET_SEQ_LEN].reset_index(drop=True)

_, ablation_df = train_test_split(
    df,
    test_size=1 - SPLIT,
    stratify=df["task"],
    random_state=SPLIT_SEED,
)
ablation_df = ablation_df.reset_index(drop=True)

print(f"Ablation set: {len(ablation_df):,} samples")
print(ablation_df.groupby("task").size().to_string())
# Out:
# Ablation set: 265 samples
# task
# ceo_lastname                 34
# employees_count_full_time    10
# employees_count_total        29
# headquarters_city            29
# headquarters_state           28
# holder_record_amount         29
# incorporation_state          32
# incorporation_year           32
# registrant_name              42

# %%
with open(HEADS_JSON_PATH, "r") as f:
    heads_data = json.load(f)

# Per-task top-K heads as (layer, head) tuples
task_head_rankings = {}
for task_id, head_list in heads_data["tasks"].items():
    task_head_rankings[task_id] = [(h["layer"], h["head"]) for h in head_list]

# Shared heads
shared_heads = [(h["layer"], h["head"]) for h in heads_data["shared_heads"]]
global_heads = [(h["layer"], h["head"]) for h in heads_data["global_heads"]]

print(f"Loaded {len(task_head_rankings)} task rankings from {HEADS_JSON_PATH}")
for tid, heads in task_head_rankings.items():
    print(f"  {tid:<35} {len(heads)} heads")
print(f"Shared heads: {len(shared_heads)}")
# Out:
# Loaded 9 task rankings from /content/rank_2026-03-10_19-23-13/ranked_heads.json
#   registrant_name                     128 heads
#   headquarters_city                   128 heads
#   headquarters_state                  128 heads
#   incorporation_state                 128 heads
#   incorporation_year                  128 heads
#   employees_count_total               128 heads
#   holder_record_amount                128 heads
#   employees_count_full_time           128 heads
#   ceo_lastname                        128 heads
# Shared heads: 101

# %% [markdown]
# ---
# ## Section 3 -- Core Ablation Infrastructure

# %%
class HeadAblationHooks:
    """Context manager that zeros out selected attention heads before o_proj."""

    def __init__(self, model, heads: list[tuple[int, int]]):
        self.model = model
        self.heads = heads
        self.handles = []
        self.head_dim = model.config.hidden_size // model.config.num_attention_heads

        # Group heads by layer for efficient hooking
        self.by_layer = {}
        for layer_idx, head_idx in heads:
            self.by_layer.setdefault(layer_idx, set()).add(head_idx)

    def __enter__(self):
        for layer_idx, layer_heads in self.by_layer.items():
            if layer_idx >= len(self.model.model.layers):
                continue
            o_proj = self.model.model.layers[layer_idx].self_attn.o_proj

            def pre_hook(_module, inputs, heads=sorted(layer_heads)):
                x = inputs[0]
                if x.ndim != 3:
                    return inputs
                x = x.clone()
                for head_idx in heads:
                    start = head_idx * self.head_dim
                    end = start + self.head_dim
                    x[..., start:end] = 0
                return (x,)

            self.handles.append(o_proj.register_forward_pre_hook(pre_hook))
        return self

    def __exit__(self, exc_type, exc_val, exc_tb):
        for handle in self.handles:
            handle.remove()
        self.handles = []

# %%
def greedy_decode(model, tokenizer, prompt_ids, max_tokens=MAX_DECODE_TOKENS) -> str:
    """Prefill + token-by-token greedy decode. No attention output needed."""
    with torch.inference_mode():
        out = model(
            input_ids=prompt_ids[:, :-1],
            use_cache=True,
            return_dict=True,
            output_attentions=False,
        )
        past_kv = out.past_key_values
        inp = prompt_ids[:, -1:]
        position = prompt_ids.size(1) - 1
        device = prompt_ids.device

        generated = []
        for _ in range(max_tokens):
            pos_ids = torch.tensor([[position]], dtype=torch.long, device=device)
            out = model(
                input_ids=inp,
                past_key_values=past_kv,
                position_ids=pos_ids,
                use_cache=True,
                output_attentions=False,
                return_dict=True,
            )
            past_kv = out.past_key_values
            next_id = out.logits[:, -1].argmax(dim=-1)
            generated.append(next_id.item())
            if next_id.item() == tokenizer.eos_token_id:
                break
            position += 1
            inp = next_id.unsqueeze(1)

    return tokenizer.decode(generated, skip_special_tokens=True).strip()

# %%
def normalize_value(text: str) -> str:
    """Lowercase, strip whitespace, remove commas, convert number words to digits."""
    if not text:
        return ""
    s = re.sub(r"\s+", " ", str(text).replace("\n", " ")).strip().lower()
    s = s.replace(",", "")

    number_words = {
        "zero": "0", "one": "1", "two": "2", "three": "3", "four": "4",
        "five": "5", "six": "6", "seven": "7", "eight": "8", "nine": "9",
        "ten": "10", "eleven": "11", "twelve": "12", "thirteen": "13",
        "fourteen": "14", "fifteen": "15", "sixteen": "16", "seventeen": "17",
        "eighteen": "18", "nineteen": "19", "twenty": "20", "thirty": "30",
        "forty": "40", "fifty": "50", "sixty": "60", "seventy": "70",
        "eighty": "80", "ninety": "90",
    }
    for word, digit in number_words.items():
        s = re.sub(r"\b" + word + r"\b", digit, s)
    return s

# %% [markdown]
# ---
# ## Section 4 -- Prompt Building & Evaluation Helpers

# %%
CONTROL_TOKENS = ["<|begin_of_text|>", "<|end_of_text|>", "<|eot_id|>", "<|start_header_id|>", "<|end_header_id|>"]
TOKEN_PATTERN = re.compile("|".join(re.escape(t) for t in CONTROL_TOKENS))


def find_needle_span(
    prompt_ids: list[int],
    needle_ids: list[int],
    threshold: float = 0.9,
) -> tuple[int, int]:
    """Locate needle tokens inside the full tokenized prompt via sliding window overlap."""
    span_len = len(needle_ids)
    if span_len == 0:
        return -1, -1

    needle_set = set(needle_ids)

    for i in range(len(prompt_ids) - span_len + 1):
        window = set(prompt_ids[i : i + span_len])
        if len(window & needle_set) / len(needle_set) >= threshold:
            return i, i + span_len

    return -1, -1


def build_prompt(row: pd.Series, task: dict, tokenizer) -> dict:
    """Construct the prompt with needle inserted at NEEDLE_DEPTH and locate the needle span."""
    haystack = TOKEN_PATTERN.sub("", row["haystack_text"]).strip()
    needle = row["needle_sentence"]

    mid = len(haystack) // 2
    context = haystack[:mid] + " " + needle + " " + haystack[mid:]

    message = f"<document>{context}</document>\nQuestion: {task['question']}\nAnswer:"
    messages = [{"role": "user", "content": message}]

    encoded = tokenizer.apply_chat_template(
        messages,
        add_generation_prompt=True,
        tokenize=True,
        return_dict=True,
        return_tensors="pt",
    )
    input_ids = encoded["input_ids"]

    # Locate needle span in the tokenized prompt
    needle_ids = tokenizer.encode(needle, add_special_tokens=False)
    needle_start, needle_end = find_needle_span(input_ids[0].tolist(), needle_ids)

    return {
        "input_ids": input_ids,
        "needle_start": needle_start,
        "needle_end": needle_end,
    }

# %%
def evaluate_sample(model, tokenizer, row, task, ablation_heads=None) -> dict:
    """Build prompt, optionally ablate heads, greedy decode, score."""
    prompt = build_prompt(row, task, tokenizer)

    if prompt["needle_start"] == -1:
        return {"decoded": "", "value_match": False, "skipped": True}

    input_ids = prompt["input_ids"].to(model.device)
    hook_ctx = HeadAblationHooks(model, ablation_heads) if ablation_heads else nullcontext()

    with hook_ctx:
        decoded = greedy_decode(model, tokenizer, input_ids)

    ground_truth = row["needle_value"]
    value_match = normalize_value(ground_truth) in normalize_value(decoded)

    del input_ids
    torch.cuda.empty_cache()

    return {"decoded": decoded, "value_match": value_match, "skipped": False}

# %%
def evaluate_condition(
    model,
    tokenizer,
    eval_df: pd.DataFrame,
    condition_name: str,
    ablation_heads=None,
) -> dict:
    """Run evaluation on all rows in eval_df. Returns per-task accuracy dict."""
    results = {}
    total = len(eval_df)

    for i, (_, row) in enumerate(eval_df.iterrows(), start=1):
        if pd.isna(row["haystack_text"]) or pd.isna(row["needle_sentence"]):
            print(f"[{condition_name}] {i}/{total} SKIP - missing text data")
            continue

        task_id = row["task"]
        task = TASK_MAP[task_id]

        if task_id not in results:
            results[task_id] = {"attempts": 0, "matches": 0, "samples": []}

        sample_result = evaluate_sample(model, tokenizer, row, task, ablation_heads)

        if sample_result["skipped"]:
            continue

        results[task_id]["attempts"] += 1
        if sample_result["value_match"]:
            results[task_id]["matches"] += 1
        results[task_id]["samples"].append(sample_result)

        if i % 10 == 0:
            print(f"[{condition_name}] {i}/{total}")

    # Compute accuracy per task
    for task_id in results:
        r = results[task_id]
        r["accuracy"] = r["matches"] / max(1, r["attempts"])

    return results

# %%
os.makedirs(ABLATION_OUTPUT_DIR, exist_ok=True)

# %% [markdown]
# ---
# ## Section 5 -- Experiment 1: Baseline Evaluation (No Ablation)

# %%
baseline_results = evaluate_condition(model, tokenizer, ablation_df, "baseline")

print("\nBaseline results:")
for task_id, r in baseline_results.items():
    print(f"  {task_id:<35} {r['matches']}/{r['attempts']}  ({r['accuracy']:.1%})")
# Out:
# [baseline] 10/265
# [baseline] 20/265
# [baseline] 30/265
# [baseline] 50/265
# [baseline] 60/265
# [baseline] 70/265
# [baseline] 80/265
# [baseline] 90/265
# [baseline] 100/265
# [baseline] 110/265
# [baseline] 120/265
# [baseline] 130/265
# [baseline] 140/265
# [baseline] 150/265
# [baseline] 160/265
# [baseline] 180/265
# [baseline] 190/265
# [baseline] 200/265
# [baseline] 210/265
# [baseline] 220/265
# [baseline] 230/265
# [baseline] 240/265
# [baseline] 250/265
# [baseline] 260/265
#
# Baseline results:
#   employees_count_total               14/28  (50.0%)
#   incorporation_year                  22/31  (71.0%)
#   registrant_name                     36/39  (92.3%)
#   headquarters_city                   22/29  (75.9%)
#   ceo_lastname                        23/31  (74.2%)
#   headquarters_state                  21/27  (77.8%)
#   incorporation_state                 24/31  (77.4%)
#   holder_record_amount                5/29  (17.2%)
#   employees_count_full_time           6/10  (60.0%)

# %%
with open(os.path.join(ABLATION_OUTPUT_DIR, "baseline_results.json"), "w") as f:
    # Strip sample-level decoded text for cleaner JSON
    export = {tid: {"attempts": r["attempts"], "matches": r["matches"], "accuracy": r["accuracy"]} for tid, r in baseline_results.items()}
    json.dump(export, f, indent=2)
    print(f"Saved baseline results.")
# Out:
# Saved baseline results.

# %% [markdown]
# ---
# ## Section 6 -- Experiment 2: Within-Task Ablation

# %% [markdown]
# For each task, ablate that task's own top-K heads at increasing K values.

# %%
within_task_results = {}

for task_id in TASK_MAP:
    task_df = ablation_df[ablation_df["task"] == task_id].reset_index(drop=True)
    if len(task_df) == 0:
        print(f"SKIP {task_id} -- no ablation samples")
        continue

    available_heads = task_head_rankings.get(task_id, [])
    if not available_heads:
        print(f"SKIP {task_id} -- no ranked heads")
        continue

    within_task_results[task_id] = {}

    for k in ABLATION_K_VALUES:
        heads_to_ablate = available_heads[:k]
        if not heads_to_ablate:
            break

        condition_name = f"within_{task_id}_k{k}"
        results = evaluate_condition(model, tokenizer, task_df, condition_name, ablation_heads=heads_to_ablate)

        r = results.get(task_id, {"attempts": 0, "matches": 0, "accuracy": 0.0})
        within_task_results[task_id][k] = {
            "k": k,
            "heads_ablated": len(heads_to_ablate),
            "attempts": r["attempts"],
            "matches": r["matches"],
            "accuracy": r["accuracy"],
        }

        print(f"  {task_id} k={k}: {r['matches']}/{r['attempts']}  ({r['accuracy']:.1%})")
# Out:
# [within_registrant_name_k8] 10/42
# [within_registrant_name_k8] 20/42
# [within_registrant_name_k8] 30/42
# [within_registrant_name_k8] 40/42
#   registrant_name k=8: 32/39  (82.1%)
# [within_registrant_name_k16] 10/42
# [within_registrant_name_k16] 20/42
# [within_registrant_name_k16] 30/42
# [within_registrant_name_k16] 40/42
#   registrant_name k=16: 29/39  (74.4%)
# [within_registrant_name_k32] 10/42
# [within_registrant_name_k32] 20/42
# [within_registrant_name_k32] 30/42
# [within_registrant_name_k32] 40/42
#   registrant_name k=32: 21/39  (53.8%)
# [within_registrant_name_k48] 10/42
# [within_registrant_name_k48] 20/42
# [within_registrant_name_k48] 30/42
# [within_registrant_name_k48] 40/42
#   registrant_name k=48: 20/39  (51.3%)
# [within_registrant_name_k64] 10/42
# [within_registrant_name_k64] 20/42
# [within_registrant_name_k64] 30/42
# [within_registrant_name_k64] 40/42
#   registrant_name k=64: 5/39  (12.8%)
# [within_registrant_name_k96] 10/42
# [within_registrant_name_k96] 20/42
# [within_registrant_name_k96] 30/42
# [within_registrant_name_k96] 40/42
#   registrant_name k=96: 0/39  (0.0%)
# [within_registrant_name_k128] 10/42
# [within_registrant_name_k128] 20/42
# [within_registrant_name_k128] 30/42
# [within_registrant_name_k128] 40/42
#   registrant_name k=128: 0/39  (0.0%)
# [within_headquarters_city_k8] 10/29
# [within_headquarters_city_k8] 20/29
#   headquarters_city k=8: 24/29  (82.8%)
# [within_headquarters_city_k16] 10/29
# [within_headquarters_city_k16] 20/29
#   headquarters_city k=16: 20/29  (69.0%)
# [within_headquarters_city_k32] 10/29
# [within_headquarters_city_k32] 20/29
#   headquarters_city k=32: 19/29  (65.5%)
# [within_headquarters_city_k48] 10/29
# [within_headquarters_city_k48] 20/29
#   headquarters_city k=48: 14/29  (48.3%)
# [within_headquarters_city_k64] 10/29
# [within_headquarters_city_k64] 20/29
#   headquarters_city k=64: 9/29  (31.0%)
# [within_headquarters_city_k96] 10/29
# [within_headquarters_city_k96] 20/29
#   headquarters_city k=96: 4/29  (13.8%)
# [within_headquarters_city_k128] 10/29
# [within_headquarters_city_k128] 20/29
#   headquarters_city k=128: 0/29  (0.0%)
# [within_headquarters_state_k8] 10/28
# [within_headquarters_state_k8] 20/28
#   headquarters_state k=8: 23/27  (85.2%)
# [within_headquarters_state_k16] 10/28
# [within_headquarters_state_k16] 20/28
#   headquarters_state k=16: 22/27  (81.5%)
# [within_headquarters_state_k32] 10/28
# [within_headquarters_state_k32] 20/28
#   headquarters_state k=32: 20/27  (74.1%)
# [within_headquarters_state_k48] 10/28
# [within_headquarters_state_k48] 20/28
#   headquarters_state k=48: 17/27  (63.0%)
# [within_headquarters_state_k64] 10/28
# [within_headquarters_state_k64] 20/28
#   headquarters_state k=64: 17/27  (63.0%)
# [within_headquarters_state_k96] 10/28
# [within_headquarters_state_k96] 20/28
#   headquarters_state k=96: 13/27  (48.1%)
# [within_headquarters_state_k128] 10/28
# [within_headquarters_state_k128] 20/28
#   headquarters_state k=128: 0/27  (0.0%)
# [within_incorporation_state_k8] 10/32
# [within_incorporation_state_k8] 20/32
# [within_incorporation_state_k8] 30/32
#   incorporation_state k=8: 26/31  (83.9%)
# [within_incorporation_state_k16] 10/32
# [within_incorporation_state_k16] 20/32
# [within_incorporation_state_k16] 30/32
#   incorporation_state k=16: 25/31  (80.6%)
# [within_incorporation_state_k32] 10/32
# [within_incorporation_state_k32] 20/32
# [within_incorporation_state_k32] 30/32
#   incorporation_state k=32: 30/31  (96.8%)
# [within_incorporation_state_k48] 10/32
# [within_incorporation_state_k48] 20/32
# [within_incorporation_state_k48] 30/32
#   incorporation_state k=48: 26/31  (83.9%)
# [within_incorporation_state_k64] 10/32
# [within_incorporation_state_k64] 20/32
# [within_incorporation_state_k64] 30/32
#   incorporation_state k=64: 5/31  (16.1%)
# [within_incorporation_state_k96] 10/32
# [within_incorporation_state_k96] 20/32
# [within_incorporation_state_k96] 30/32
#   incorporation_state k=96: 20/31  (64.5%)
# [within_incorporation_state_k128] 10/32
# [within_incorporation_state_k128] 20/32
# [within_incorporation_state_k128] 30/32
#   incorporation_state k=128: 8/31  (25.8%)
# [within_incorporation_year_k8] 10/32
# [within_incorporation_year_k8] 20/32
# [within_incorporation_year_k8] 30/32
#   incorporation_year k=8: 22/31  (71.0%)
# [within_incorporation_year_k16] 10/32
# [within_incorporation_year_k16] 20/32
# [within_incorporation_year_k16] 30/32
#   incorporation_year k=16: 21/31  (67.7%)
# [within_incorporation_year_k32] 10/32
# [within_incorporation_year_k32] 20/32
# [within_incorporation_year_k32] 30/32
#   incorporation_year k=32: 19/31  (61.3%)
# [within_incorporation_year_k48] 10/32
# [within_incorporation_year_k48] 20/32
# [within_incorporation_year_k48] 30/32
#   incorporation_year k=48: 19/31  (61.3%)
# [within_incorporation_year_k64] 10/32
# [within_incorporation_year_k64] 20/32
# [within_incorporation_year_k64] 30/32
#   incorporation_year k=64: 16/31  (51.6%)
# [within_incorporation_year_k96] 10/32
# [within_incorporation_year_k96] 20/32
# [within_incorporation_year_k96] 30/32
#   incorporation_year k=96: 9/31  (29.0%)
# [within_incorporation_year_k128] 10/32
# [within_incorporation_year_k128] 20/32
# [within_incorporation_year_k128] 30/32
#   incorporation_year k=128: 1/31  (3.2%)
# [within_employees_count_total_k8] 10/29
# [within_employees_count_total_k8] 20/29
#   employees_count_total k=8: 24/28  (85.7%)
# [within_employees_count_total_k16] 10/29
# [within_employees_count_total_k16] 20/29
#   employees_count_total k=16: 14/28  (50.0%)
# [within_employees_count_total_k32] 10/29
# [within_employees_count_total_k32] 20/29
#   employees_count_total k=32: 11/28  (39.3%)
# [within_employees_count_total_k48] 10/29
# [within_employees_count_total_k48] 20/29
#   employees_count_total k=48: 0/28  (0.0%)
# [within_employees_count_total_k64] 10/29
# [within_employees_count_total_k64] 20/29
#   employees_count_total k=64: 0/28  (0.0%)
# [within_employees_count_total_k96] 10/29
# [within_employees_count_total_k96] 20/29
#   employees_count_total k=96: 0/28  (0.0%)
# [within_employees_count_total_k128] 10/29
# [within_employees_count_total_k128] 20/29
#   employees_count_total k=128: 0/28  (0.0%)
# [within_holder_record_amount_k8] 10/29
# [within_holder_record_amount_k8] 20/29
#   holder_record_amount k=8: 1/29  (3.4%)
# [within_holder_record_amount_k16] 10/29
# [within_holder_record_amount_k16] 20/29
#   holder_record_amount k=16: 0/29  (0.0%)
# [within_holder_record_amount_k32] 10/29
# [within_holder_record_amount_k32] 20/29
#   holder_record_amount k=32: 2/29  (6.9%)
# [within_holder_record_amount_k48] 10/29
# [within_holder_record_amount_k48] 20/29
#   holder_record_amount k=48: 1/29  (3.4%)
# [within_holder_record_amount_k64] 10/29
# [within_holder_record_amount_k64] 20/29
#   holder_record_amount k=64: 0/29  (0.0%)
# [within_holder_record_amount_k96] 10/29
# [within_holder_record_amount_k96] 20/29
#   holder_record_amount k=96: 0/29  (0.0%)
# [within_holder_record_amount_k128] 10/29
# [within_holder_record_amount_k128] 20/29
#   holder_record_amount k=128: 0/29  (0.0%)
# [within_employees_count_full_time_k8] 10/10
#   employees_count_full_time k=8: 8/10  (80.0%)
# [within_employees_count_full_time_k16] 10/10
#   employees_count_full_time k=16: 8/10  (80.0%)
# [within_employees_count_full_time_k32] 10/10
#   employees_count_full_time k=32: 7/10  (70.0%)
# [within_employees_count_full_time_k48] 10/10
#   employees_count_full_time k=48: 3/10  (30.0%)
# [within_employees_count_full_time_k64] 10/10
#   employees_count_full_time k=64: 4/10  (40.0%)
# [within_employees_count_full_time_k96] 10/10
#   employees_count_full_time k=96: 0/10  (0.0%)
# [within_employees_count_full_time_k128] 10/10
#   employees_count_full_time k=128: 0/10  (0.0%)
# [within_ceo_lastname_k8] 10/34
# [within_ceo_lastname_k8] 20/34
# [within_ceo_lastname_k8] 30/34
#   ceo_lastname k=8: 19/31  (61.3%)
# [within_ceo_lastname_k16] 10/34
# [within_ceo_lastname_k16] 20/34
# [within_ceo_lastname_k16] 30/34
#   ceo_lastname k=16: 15/31  (48.4%)
# [within_ceo_lastname_k32] 10/34
# [within_ceo_lastname_k32] 20/34
# [within_ceo_lastname_k32] 30/34
#   ceo_lastname k=32: 0/31  (0.0%)
# [within_ceo_lastname_k48] 10/34
# [within_ceo_lastname_k48] 20/34
# [within_ceo_lastname_k48] 30/34
#   ceo_lastname k=48: 0/31  (0.0%)
# [within_ceo_lastname_k64] 10/34
# [within_ceo_lastname_k64] 20/34
# [within_ceo_lastname_k64] 30/34
#   ceo_lastname k=64: 0/31  (0.0%)
# [within_ceo_lastname_k96] 10/34
# [within_ceo_lastname_k96] 20/34
# [within_ceo_lastname_k96] 30/34
#   ceo_lastname k=96: 0/31  (0.0%)
# [within_ceo_lastname_k128] 10/34
# [within_ceo_lastname_k128] 20/34
# [within_ceo_lastname_k128] 30/34
#   ceo_lastname k=128: 0/31  (0.0%)

# %%
with open(os.path.join(ABLATION_OUTPUT_DIR, "within_task_ablation.json"), "w") as f:
    json.dump(within_task_results, f, indent=2)
    print("Saved within-task ablation results.")
# Out:
# Saved within-task ablation results.

# %% [markdown]
# ---
# ## Section 7 -- Experiment 3: Across-Task Ablation (Shared Heads)

# %% [markdown]
# Ablate the global shared retrieval heads and measure accuracy across all tasks.

# %%
across_task_results = {}

for k in ABLATION_K_VALUES:
    heads_to_ablate = shared_heads[:k]
    if not heads_to_ablate:
        print(f"Only {len(shared_heads)} shared heads available, stopping at k={k}")
        break

    condition_name = f"across_task_k{k}"
    results = evaluate_condition(model, tokenizer, ablation_df, condition_name, ablation_heads=heads_to_ablate)

    total_attempts = sum(r["attempts"] for r in results.values())
    total_matches  = sum(r["matches"] for r in results.values())
    overall_acc    = total_matches / max(1, total_attempts)

    across_task_results[k] = {
        "k": k,
        "heads_ablated": len(heads_to_ablate),
        "overall_accuracy": overall_acc,
        "total_attempts": total_attempts,
        "total_matches": total_matches,
        "per_task": {tid: {"attempts": r["attempts"], "matches": r["matches"], "accuracy": r["accuracy"]} for tid, r in results.items()},
    }

    print(f"k={k}: {total_matches}/{total_attempts}  ({overall_acc:.1%})")
# Out:
# [across_task_k8] 10/265
# [across_task_k8] 20/265
# [across_task_k8] 30/265
# [across_task_k8] 50/265
# [across_task_k8] 60/265
# [across_task_k8] 70/265
# [across_task_k8] 80/265
# [across_task_k8] 90/265
# [across_task_k8] 100/265
# [across_task_k8] 110/265
# [across_task_k8] 120/265
# [across_task_k8] 130/265
# [across_task_k8] 140/265
# [across_task_k8] 150/265
# [across_task_k8] 160/265
# [across_task_k8] 180/265
# [across_task_k8] 190/265
# [across_task_k8] 200/265
# [across_task_k8] 210/265
# [across_task_k8] 220/265
# [across_task_k8] 230/265
# [across_task_k8] 240/265
# [across_task_k8] 250/265
# [across_task_k8] 260/265
# k=8: 172/255  (67.5%)
# [across_task_k16] 10/265
# [across_task_k16] 20/265
# [across_task_k16] 30/265
# [across_task_k16] 50/265
# [across_task_k16] 60/265
# [across_task_k16] 70/265
# [across_task_k16] 80/265
# [across_task_k16] 90/265
# [across_task_k16] 100/265
# [across_task_k16] 110/265
# [across_task_k16] 120/265
# [across_task_k16] 130/265
# [across_task_k16] 140/265
# [across_task_k16] 150/265
# [across_task_k16] 160/265
# [across_task_k16] 180/265
# [across_task_k16] 190/265
# [across_task_k16] 200/265
# [across_task_k16] 210/265
# [across_task_k16] 220/265
# [across_task_k16] 230/265
# [across_task_k16] 240/265
# [across_task_k16] 250/265
# [across_task_k16] 260/265
# k=16: 170/255  (66.7%)
# [across_task_k32] 10/265
# [across_task_k32] 20/265
# [across_task_k32] 30/265
# [across_task_k32] 50/265
# [across_task_k32] 60/265
# [across_task_k32] 70/265
# [across_task_k32] 80/265
# [across_task_k32] 90/265
# [across_task_k32] 100/265
# [across_task_k32] 110/265
# [across_task_k32] 120/265
# [across_task_k32] 130/265
# [across_task_k32] 140/265
# [across_task_k32] 150/265
# [across_task_k32] 160/265
# [across_task_k32] 180/265
# [across_task_k32] 190/265
# [across_task_k32] 200/265
# [across_task_k32] 210/265
# [across_task_k32] 220/265
# [across_task_k32] 230/265
# [across_task_k32] 240/265
# [across_task_k32] 250/265
# [across_task_k32] 260/265
# k=32: 128/255  (50.2%)
# [across_task_k48] 10/265
# [across_task_k48] 20/265
# [across_task_k48] 30/265
# [across_task_k48] 50/265
# [across_task_k48] 60/265
# [across_task_k48] 70/265
# [across_task_k48] 80/265
# [across_task_k48] 90/265
# [across_task_k48] 100/265
# [across_task_k48] 110/265
# [across_task_k48] 120/265
# [across_task_k48] 130/265
# [across_task_k48] 140/265
# [across_task_k48] 150/265
# [across_task_k48] 160/265
# [across_task_k48] 180/265
# [across_task_k48] 190/265
# [across_task_k48] 200/265
# [across_task_k48] 210/265
# [across_task_k48] 220/265
# [across_task_k48] 230/265
# [across_task_k48] 240/265
# [across_task_k48] 250/265
# [across_task_k48] 260/265
# k=48: 34/255  (13.3%)
# [across_task_k64] 10/265
# [across_task_k64] 20/265
# [across_task_k64] 30/265
# [across_task_k64] 50/265
# [across_task_k64] 60/265
# [across_task_k64] 70/265
# [across_task_k64] 80/265
# [across_task_k64] 90/265
# [across_task_k64] 100/265
# [across_task_k64] 110/265
# [across_task_k64] 120/265
# [across_task_k64] 130/265
# [across_task_k64] 140/265
# [across_task_k64] 150/265
# [across_task_k64] 160/265
# [across_task_k64] 180/265
# [across_task_k64] 190/265
# [across_task_k64] 200/265
# [across_task_k64] 210/265
# [across_task_k64] 220/265
# [across_task_k64] 230/265
# [across_task_k64] 240/265
# [across_task_k64] 250/265
# [across_task_k64] 260/265
# k=64: 26/255  (10.2%)
# [across_task_k96] 10/265
# [across_task_k96] 20/265
# [across_task_k96] 30/265
# [across_task_k96] 50/265
# [across_task_k96] 60/265
# [across_task_k96] 70/265
# [across_task_k96] 80/265
# [across_task_k96] 90/265
# [across_task_k96] 100/265
# [across_task_k96] 110/265
# [across_task_k96] 120/265
# [across_task_k96] 130/265
# [across_task_k96] 140/265
# [across_task_k96] 150/265
# [across_task_k96] 160/265
# [across_task_k96] 180/265
# [across_task_k96] 190/265
# [across_task_k96] 200/265
# [across_task_k96] 210/265
# [across_task_k96] 220/265
# [across_task_k96] 230/265
# [across_task_k96] 240/265
# [across_task_k96] 250/265
# [across_task_k96] 260/265
# k=96: 24/255  (9.4%)
# [across_task_k128] 10/265
# [across_task_k128] 20/265
# [across_task_k128] 30/265
# [across_task_k128] 50/265
# [across_task_k128] 60/265
# [across_task_k128] 70/265
# [across_task_k128] 80/265
# [across_task_k128] 90/265
# [across_task_k128] 100/265
# [across_task_k128] 110/265
# [across_task_k128] 120/265
# [across_task_k128] 130/265
# [across_task_k128] 140/265
# [across_task_k128] 150/265
# [across_task_k128] 160/265
# [across_task_k128] 180/265
# [across_task_k128] 190/265
# [across_task_k128] 200/265
# [across_task_k128] 210/265
# [across_task_k128] 220/265
# [across_task_k128] 230/265
# [across_task_k128] 240/265
# [across_task_k128] 250/265
# [across_task_k128] 260/265
# k=128: 19/255  (7.5%)

# %%
with open(os.path.join(ABLATION_OUTPUT_DIR, "across_task_ablation.json"), "w") as f:
    json.dump(across_task_results, f, indent=2)
    print("Saved across-task ablation results.")
# Out:
# Saved across-task ablation results.

# %% [markdown]
# ---
# ## Section 7b -- Experiment 4: Global Heads Ablation
# Ablate the global powerhouse retrieval heads and measure accuracy across all tasks.

# %%
global_task_results = {}

for k in ABLATION_K_VALUES:
    heads_to_ablate = global_heads[:k]
    if not heads_to_ablate:
        print(f"Only {len(global_heads)} global heads available, stopping at k={k}")
        break

    condition_name = f"global_task_k{k}"
    results = evaluate_condition(model, tokenizer, ablation_df, condition_name, ablation_heads=heads_to_ablate)

    total_attempts = sum(r["attempts"] for r in results.values())
    total_matches  = sum(r["matches"] for r in results.values())
    overall_acc    = total_matches / max(1, total_attempts)

    global_task_results[k] = {
        "k": k,
        "heads_ablated": len(heads_to_ablate),
        "overall_accuracy": overall_acc,
        "total_attempts": total_attempts,
        "total_matches": total_matches,
        "per_task": {tid: {"attempts": r["attempts"], "matches": r["matches"], "accuracy": r["accuracy"]} for tid, r in results.items()},
    }

    print(f"Global k={k}: {total_matches}/{total_attempts}  ({overall_acc:.1%})")

with open(os.path.join(ABLATION_OUTPUT_DIR, "global_ablation.json"), "w") as f:
    json.dump(global_task_results, f, indent=2)
    print("Saved global-task ablation results.")
# Out:
# [global_task_k8] 10/265
# [global_task_k8] 20/265
# [global_task_k8] 30/265
# [global_task_k8] 50/265
# [global_task_k8] 60/265
# [global_task_k8] 70/265
# [global_task_k8] 80/265
# [global_task_k8] 90/265
# [global_task_k8] 100/265
# [global_task_k8] 110/265
# [global_task_k8] 120/265
# [global_task_k8] 130/265
# [global_task_k8] 140/265
# [global_task_k8] 150/265
# [global_task_k8] 160/265
# [global_task_k8] 180/265
# [global_task_k8] 190/265
# [global_task_k8] 200/265
# [global_task_k8] 210/265
# [global_task_k8] 220/265
# [global_task_k8] 230/265
# [global_task_k8] 240/265
# [global_task_k8] 250/265
# [global_task_k8] 260/265
# Global k=8: 173/255  (67.8%)
# [global_task_k16] 10/265
# [global_task_k16] 20/265
# [global_task_k16] 30/265
# [global_task_k16] 50/265
# [global_task_k16] 60/265
# [global_task_k16] 70/265
# [global_task_k16] 80/265
# [global_task_k16] 90/265
# [global_task_k16] 100/265
# [global_task_k16] 110/265
# [global_task_k16] 120/265
# [global_task_k16] 130/265
# [global_task_k16] 140/265
# [global_task_k16] 150/265
# [global_task_k16] 160/265
# [global_task_k16] 180/265
# [global_task_k16] 190/265
# [global_task_k16] 200/265
# [global_task_k16] 210/265
# [global_task_k16] 220/265
# [global_task_k16] 230/265
# [global_task_k16] 240/265
# [global_task_k16] 250/265
# [global_task_k16] 260/265
# Global k=16: 168/255  (65.9%)
# [global_task_k32] 10/265
# [global_task_k32] 20/265
# [global_task_k32] 30/265
# [global_task_k32] 50/265
# [global_task_k32] 60/265
# [global_task_k32] 70/265
# [global_task_k32] 80/265
# [global_task_k32] 90/265
# [global_task_k32] 100/265
# [global_task_k32] 110/265
# [global_task_k32] 120/265
# [global_task_k32] 130/265
# [global_task_k32] 140/265
# [global_task_k32] 150/265
# [global_task_k32] 160/265
# [global_task_k32] 180/265
# [global_task_k32] 190/265
# [global_task_k32] 200/265
# [global_task_k32] 210/265
# [global_task_k32] 220/265
# [global_task_k32] 230/265
# [global_task_k32] 240/265
# [global_task_k32] 250/265
# [global_task_k32] 260/265
# Global k=32: 132/255  (51.8%)
# [global_task_k48] 10/265
# [global_task_k48] 20/265
# [global_task_k48] 30/265
# [global_task_k48] 50/265
# [global_task_k48] 60/265
# [global_task_k48] 70/265
# [global_task_k48] 80/265
# [global_task_k48] 90/265
# [global_task_k48] 100/265
# [global_task_k48] 110/265
# [global_task_k48] 120/265
# [global_task_k48] 130/265
# [global_task_k48] 140/265
# [global_task_k48] 150/265
# [global_task_k48] 160/265
# [global_task_k48] 180/265
# [global_task_k48] 190/265
# [global_task_k48] 200/265
# [global_task_k48] 210/265
# [global_task_k48] 220/265
# [global_task_k48] 230/265
# [global_task_k48] 240/265
# [global_task_k48] 250/265
# [global_task_k48] 260/265
# Global k=48: 34/255  (13.3%)
# [global_task_k64] 10/265
# [global_task_k64] 20/265
# [global_task_k64] 30/265
# [global_task_k64] 50/265
# [global_task_k64] 60/265
# [global_task_k64] 70/265
# [global_task_k64] 80/265
# [global_task_k64] 90/265
# [global_task_k64] 100/265
# [global_task_k64] 110/265
# [global_task_k64] 120/265
# [global_task_k64] 130/265
# [global_task_k64] 140/265
# [global_task_k64] 150/265
# [global_task_k64] 160/265
# [global_task_k64] 180/265
# [global_task_k64] 190/265
# [global_task_k64] 200/265
# [global_task_k64] 210/265
# [global_task_k64] 220/265
# [global_task_k64] 230/265
# [global_task_k64] 240/265
# [global_task_k64] 250/265
# [global_task_k64] 260/265
# Global k=64: 31/255  (12.2%)
# [global_task_k96] 10/265
# [global_task_k96] 20/265
# [global_task_k96] 30/265
# [global_task_k96] 50/265
# [global_task_k96] 60/265
# [global_task_k96] 70/265
# [global_task_k96] 80/265
# [global_task_k96] 90/265
# [global_task_k96] 100/265
# [global_task_k96] 110/265
# [global_task_k96] 120/265
# [global_task_k96] 130/265
# [global_task_k96] 140/265
# [global_task_k96] 150/265
# [global_task_k96] 160/265
# [global_task_k96] 180/265
# [global_task_k96] 190/265
# [global_task_k96] 200/265
# [global_task_k96] 210/265
# [global_task_k96] 220/265
# [global_task_k96] 230/265
# [global_task_k96] 240/265
# [global_task_k96] 250/265
# [global_task_k96] 260/265
# Global k=96: 44/255  (17.3%)
# [global_task_k128] 10/265
# [global_task_k128] 20/265
# [global_task_k128] 30/265
# [global_task_k128] 50/265
# [global_task_k128] 60/265
# [global_task_k128] 70/265
# [global_task_k128] 80/265
# [global_task_k128] 90/265
# [global_task_k128] 100/265
# [global_task_k128] 110/265
# [global_task_k128] 120/265
# [global_task_k128] 130/265
# [global_task_k128] 140/265
# [global_task_k128] 150/265
# [global_task_k128] 160/265
# [global_task_k128] 180/265
# [global_task_k128] 190/265
# [global_task_k128] 200/265
# [global_task_k128] 210/265
# [global_task_k128] 220/265
# [global_task_k128] 230/265
# [global_task_k128] 240/265
# [global_task_k128] 250/265
# [global_task_k128] 260/265
# Global k=128: 1/255  (0.4%)
# Saved global-task ablation results.

# %% [markdown]
# ---
# ## Section 8 -- Random Head Ablation Control

# %% [markdown]
# Ablate randomly selected heads to prove the accuracy drop is specific to retrieval heads.

# %%
num_layers = model.config.num_hidden_layers
num_heads = model.config.num_attention_heads

# All possible (layer, head) pairs, excluding the shared retrieval heads
shared_set = set(shared_heads)
all_heads = [(l, h) for l in range(num_layers) for h in range(num_heads) if (l, h) not in shared_set]

random.seed(SPLIT_SEED)
random_pool = random.sample(all_heads, min(max(ABLATION_K_VALUES), len(all_heads)))

random_ablation_results = {}

for k in ABLATION_K_VALUES:
    heads_to_ablate = random_pool[:k]

    condition_name = f"random_k{k}"
    results = evaluate_condition(model, tokenizer, ablation_df, condition_name, ablation_heads=heads_to_ablate)

    total_attempts = sum(r["attempts"] for r in results.values())
    total_matches  = sum(r["matches"] for r in results.values())
    overall_acc    = total_matches / max(1, total_attempts)

    random_ablation_results[k] = {
        "k": k,
        "heads_ablated": [(l, h) for l, h in heads_to_ablate],
        "overall_accuracy": overall_acc,
        "total_attempts": total_attempts,
        "total_matches": total_matches,
        "per_task": {tid: {"attempts": r["attempts"], "matches": r["matches"], "accuracy": r["accuracy"]} for tid, r in results.items()},
    }

    print(f"random k={k}: {total_matches}/{total_attempts}  ({overall_acc:.1%})")
# Out:
# [random_k8] 10/265
# [random_k8] 20/265
# [random_k8] 30/265
# [random_k8] 50/265
# [random_k8] 60/265
# [random_k8] 70/265
# [random_k8] 80/265
# [random_k8] 90/265
# [random_k8] 100/265
# [random_k8] 110/265
# [random_k8] 120/265
# [random_k8] 130/265
# [random_k8] 140/265
# [random_k8] 150/265
# [random_k8] 160/265
# [random_k8] 180/265
# [random_k8] 190/265
# [random_k8] 200/265
# [random_k8] 210/265
# [random_k8] 220/265
# [random_k8] 230/265
# [random_k8] 240/265
# [random_k8] 250/265
# [random_k8] 260/265
# random k=8: 165/255  (64.7%)
# [random_k16] 10/265
# [random_k16] 20/265
# [random_k16] 30/265
# [random_k16] 50/265
# [random_k16] 60/265
# [random_k16] 70/265
# [random_k16] 80/265
# [random_k16] 90/265
# [random_k16] 100/265
# [random_k16] 110/265
# [random_k16] 120/265
# [random_k16] 130/265
# [random_k16] 140/265
# [random_k16] 150/265
# [random_k16] 160/265
# [random_k16] 180/265
# [random_k16] 190/265
# [random_k16] 200/265
# [random_k16] 210/265
# [random_k16] 220/265
# [random_k16] 230/265
# [random_k16] 240/265
# [random_k16] 250/265
# [random_k16] 260/265
# random k=16: 167/255  (65.5%)
# [random_k32] 10/265
# [random_k32] 20/265
# [random_k32] 30/265
# [random_k32] 50/265
# [random_k32] 60/265
# [random_k32] 70/265
# [random_k32] 80/265
# [random_k32] 90/265
# [random_k32] 100/265
# [random_k32] 110/265
# [random_k32] 120/265
# [random_k32] 130/265
# [random_k32] 140/265
# [random_k32] 150/265
# [random_k32] 160/265
# [random_k32] 180/265
# [random_k32] 190/265
# [random_k32] 200/265
# [random_k32] 210/265
# [random_k32] 220/265
# [random_k32] 230/265
# [random_k32] 240/265
# [random_k32] 250/265
# [random_k32] 260/265
# random k=32: 171/255  (67.1%)
# [random_k48] 10/265
# [random_k48] 20/265
# [random_k48] 30/265
# [random_k48] 50/265
# [random_k48] 60/265
# [random_k48] 70/265
# [random_k48] 80/265
# [random_k48] 90/265
# [random_k48] 100/265
# [random_k48] 110/265
# [random_k48] 120/265
# [random_k48] 130/265
# [random_k48] 140/265
# [random_k48] 150/265
# [random_k48] 160/265
# [random_k48] 180/265
# [random_k48] 190/265
# [random_k48] 200/265
# [random_k48] 210/265
# [random_k48] 220/265
# [random_k48] 230/265
# [random_k48] 240/265
# [random_k48] 250/265
# [random_k48] 260/265
# random k=48: 174/255  (68.2%)
# [random_k64] 10/265
# [random_k64] 20/265
# [random_k64] 30/265
# [random_k64] 50/265
# [random_k64] 60/265
# [random_k64] 70/265
# [random_k64] 80/265
# [random_k64] 90/265
# [random_k64] 100/265
# [random_k64] 110/265
# [random_k64] 120/265
# [random_k64] 130/265
# [random_k64] 140/265
# [random_k64] 150/265
# [random_k64] 160/265
# [random_k64] 180/265
# [random_k64] 190/265
# [random_k64] 200/265
# [random_k64] 210/265
# [random_k64] 220/265
# [random_k64] 230/265
# [random_k64] 240/265
# [random_k64] 250/265
# [random_k64] 260/265
# random k=64: 180/255  (70.6%)
# [random_k96] 10/265
# [random_k96] 20/265
# [random_k96] 30/265
# [random_k96] 50/265
# [random_k96] 60/265
# [random_k96] 70/265
# [random_k96] 80/265
# [random_k96] 90/265
# [random_k96] 100/265
# [random_k96] 110/265
# [random_k96] 120/265
# [random_k96] 130/265
# [random_k96] 140/265
# [random_k96] 150/265
# [random_k96] 160/265
# [random_k96] 180/265
# [random_k96] 190/265
# [random_k96] 200/265
# [random_k96] 210/265
# [random_k96] 220/265
# [random_k96] 230/265
# [random_k96] 240/265
# [random_k96] 250/265
# [random_k96] 260/265
# random k=96: 150/255  (58.8%)
# [random_k128] 10/265
# [random_k128] 20/265
# [random_k128] 30/265
# [random_k128] 50/265
# [random_k128] 60/265
# [random_k128] 70/265
# [random_k128] 80/265
# [random_k128] 90/265
# [random_k128] 100/265
# [random_k128] 110/265
# [random_k128] 120/265
# [random_k128] 130/265
# [random_k128] 140/265
# [random_k128] 150/265
# [random_k128] 160/265
# [random_k128] 180/265
# [random_k128] 190/265
# [random_k128] 200/265
# [random_k128] 210/265
# [random_k128] 220/265
# [random_k128] 230/265
# [random_k128] 240/265
# [random_k128] 250/265
# [random_k128] 260/265
# random k=128: 18/255  (7.1%)

# %%
with open(os.path.join(ABLATION_OUTPUT_DIR, "random_ablation_control.json"), "w") as f:
    json.dump(random_ablation_results, f, indent=2)
    print("Saved random ablation control results.")

# %%
meta = {
    "source_ranking": RANKING_RUN_NAME,
    "timestamp": TIMESTAMP,
    "ablation_k_values": ABLATION_K_VALUES
}

# If SOURCE_MODEL exists also include it in meta
if SOURCE_MODEL:
    meta["source_model"] = SOURCE_MODEL

with open(os.path.join(ABLATION_OUTPUT_DIR, "meta.json"), "w") as f:
    json.dump(meta, f, indent=2)
print("Saved meta.json")
# Out:
# Saved meta.json

# %%
import shutil
from google.colab import files

# Define the folder path and the output zip file name
folder_path = '/content/ablation_2026-03-11_10-00-32'
output_filename = '/content/ablation_2026-03-11_10-00-32.zip'

# Create a zip file of the folder
shutil.make_archive(output_filename.replace('.zip', ''), 'zip', folder_path)

print(f"Zipped folder to {output_filename}")

# Trigger the download
files.download(output_filename)
# Out:
# Zipped folder to /content/ablation_2026-03-11_10-00-32.zip
