# %% [markdown]
# # Retrieval Head Ablation (Step 2)

# %% [markdown]
# ### Validate identified retrieval heads via targeted ablation on held-out data

# %%
# %pip install torch transformers numpy huggingface_hub accelerate bitsandbytes python-dotenv pandas matplotlib scikit-learn
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (2.10.0+cu128)
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (5.0.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (2.0.2)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.12/dist-packages (1.5.0)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.12/dist-packages (1.12.0)
# Collecting bitsandbytes
#   Downloading bitsandbytes-0.49.2-py3-none-manylinux_2_24_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.12/dist-packages (1.2.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (1.6.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch) (3.24.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch) (2025.3.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch) (1.4.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (26.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.22.2)
# Requirement already satisfied: typer-slim in /usr/local/lib/python3.12/dist-packages (from transformers) (0.24.0)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers) (4.67.3)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (1.3.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (0.28.1)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (0.24.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub) (4.12.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface_hub) (0.16.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch) (3.0.3)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface_hub) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface_hub) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface_hub) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface_hub) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface_hub) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface_hub) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->huggingface_hub) (0.1.2)
# Downloading bitsandbytes-0.49.2-py3-none-manylinux_2_24_x86_64.whl (60.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.7/60.7 MB 43.0 MB/s eta 0:00:00
# Installing collected packages: bitsandbytes
# Successfully installed bitsandbytes-0.49.2

# %%
import os
import re
import json
import random
import torch
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from contextlib import nullcontext
from collections import Counter
from transformers import AutoTokenizer, AutoModelForCausalLM
from huggingface_hub import login
from dotenv import load_dotenv

# %% [markdown]
# #### If using Google Colab: Run The Following Cells (Ignore if using some other environment)

# %%
from google.colab import userdata

HF_TOKEN = userdata.get('HF_TOKEN')

# %%
if HF_TOKEN:
    login(token=HF_TOKEN)
    print("HF_TOKEN loaded and Hugging Face login successful.")
else:
    print("HF_TOKEN not found.")
# Out:
# HF_TOKEN loaded and Hugging Face login successful.

# %% [markdown]
# #### If using a high end GPU not from Colab, but from Lambda Labs

# %%
load_dotenv(override=False)

HF_TOKEN = os.getenv("HF_TOKEN") or globals().get("HF_TOKEN")

if HF_TOKEN:
    os.environ["HF_TOKEN"] = HF_TOKEN
    login(token=HF_TOKEN)
    print("HF_TOKEN loaded and Hugging Face login successful.")
else:
    print("HF_TOKEN not found. Add HF_TOKEN=... to your .env file or set it in the environment.")

# %% [markdown]
# #### Configuration & Hyperparameters

# %%
MODEL_ID = "meta-llama/Meta-Llama-3-8B-Instruct"

TARGET_SEQ_LEN = 7000
NEEDLE_DEPTH = 0.5
SPLIT = 0.8
SPLIT_SEED = 42

TASKS = [
    {"id": "registrant_name", "question": "What is the registrant's name?"},
    {"id": "headquarters_city", "question": "What is the registrant's headquarters city?"},
    {"id": "headquarters_state", "question": "What is the registrant's headquarters state?"},
    {"id": "incorporation_state", "question": "What is the registrant's incorporation state?"},
    {"id": "incorporation_year", "question": "What is the incorporation year?"},
    {"id": "employees_count_total", "question": "How many total employees does the registrant have?"},
    {"id": "holder_record_amount", "question": "What is the number of holders of record of the registrant's common stock?"},
    {"id": "employees_count_full_time", "question": "How many full-time employees does the registrant have?"},
    {"id": "ceo_lastname", "question": "What is the CEO's last name?"},
]
TASK_MAP = {t["id"]: t for t in TASKS}

# Paths
DATA_PATH = "/content/cleaned_EDGAR_gt_2-22-2026.csv"

HEADS_JSON_PATH = "/content/retrieval_heads.json" # Copy paste path because this is now dynamically timestamped based on the run

BASE_OUTPUT_DIR = os.path.dirname(os.path.dirname(HEADS_JSON_PATH))
ABLATION_OUTPUT_DIR = f"{BASE_OUTPUT_DIR}/ablation_results"

# Ablation-specific config
ABLATION_K_VALUES = [1, 2, 5, 10, 20, 30, 40, 50]
MAX_DECODE_TOKENS = 20

# Model loading
TORCH_DTYPE = torch.bfloat16
ATTN_IMPL = "eager"

print("Configuration loaded.")
print(f"Model: {MODEL_ID}")
print(f"Ablation K values: {ABLATION_K_VALUES}")
print(f"Max decode tokens: {MAX_DECODE_TOKENS}")
print(f"Heads JSON: {HEADS_JSON_PATH}")
# Out:
# Configuration loaded.
# Model: meta-llama/Meta-Llama-3-8B-Instruct
# Ablation K values: [1, 2, 5, 10, 20, 30, 40, 50]
# Max decode tokens: 20
# Heads JSON: /content/retrieval_heads.json

# %% [markdown]
# ##### Tokenizer & Model Loading

# %%
tokenizer = AutoTokenizer.from_pretrained(MODEL_ID, token=HF_TOKEN)

if tokenizer.pad_token is None:
    tokenizer.pad_token = tokenizer.eos_token

print(f"Tokenizer loaded: {MODEL_ID}")
print(f"Vocab size: {tokenizer.vocab_size:,}")
# Out:
# config.json:   0%|          | 0.00/654 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/73.0 [00:00<?, ?B/s]
# Tokenizer loaded: meta-llama/Meta-Llama-3-8B-Instruct
# Vocab size: 128,000

# %%
model = AutoModelForCausalLM.from_pretrained(
    MODEL_ID,
    token=HF_TOKEN,
    torch_dtype=TORCH_DTYPE,
    device_map="auto",
    attn_implementation=ATTN_IMPL,
)
model.eval()

print(f"Model loaded: {MODEL_ID}")
print(f"dtype: {next(model.parameters()).dtype}")
print(f"Num layers: {model.config.num_hidden_layers}")
print(f"Num heads (Q): {model.config.num_attention_heads}")
print(f"Num KV heads: {model.config.num_key_value_heads}")
# Out:
# `torch_dtype` is deprecated! Use `dtype` instead!
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 4 files:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/291 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/187 [00:00<?, ?B/s]
# Model loaded: meta-llama/Meta-Llama-3-8B-Instruct
# dtype: torch.bfloat16
# Num layers: 32
# Num heads (Q): 32
# Num KV heads: 8

# %% [markdown]
# ---
# ## Section 2 -- Load Ablation Split & Identified Heads

# %%
from sklearn.model_selection import train_test_split

df = pd.read_csv(DATA_PATH)
df = df[df["haystack_token_length"] == TARGET_SEQ_LEN].reset_index(drop=True)

_, ablation_df = train_test_split(
    df,
    test_size=1 - SPLIT,
    stratify=df["task"],
    random_state=SPLIT_SEED,
)
ablation_df = ablation_df.reset_index(drop=True)

print(f"Ablation set: {len(ablation_df):,} samples")
print(ablation_df.groupby("task").size().to_string())
# Out:
# Ablation set: 265 samples
# task
# ceo_lastname                 34
# employees_count_full_time    10
# employees_count_total        29
# headquarters_city            29
# headquarters_state           28
# holder_record_amount         29
# incorporation_state          32
# incorporation_year           32
# registrant_name              42

# %%
with open(HEADS_JSON_PATH, "r") as f:
    heads_data = json.load(f)

# Per-task top-K heads as (layer, head) tuples
task_head_rankings = {}
for task_id, head_list in heads_data["tasks"].items():
    task_head_rankings[task_id] = [(h["layer"], h["head"]) for h in head_list]

# Shared heads
shared_heads = [(h["layer"], h["head"]) for h in heads_data["shared_heads"]]

print(f"Loaded {len(task_head_rankings)} task rankings from {HEADS_JSON_PATH}")
for tid, heads in task_head_rankings.items():
    print(f"  {tid:<35} {len(heads)} heads")
print(f"Shared heads: {len(shared_heads)}")
# Out:
# Loaded 9 task rankings from /content/retrieval_heads.json
#   registrant_name                     20 heads
#   headquarters_city                   20 heads
#   headquarters_state                  20 heads
#   incorporation_state                 20 heads
#   incorporation_year                  20 heads
#   employees_count_total               20 heads
#   holder_record_amount                20 heads
#   employees_count_full_time           20 heads
#   ceo_lastname                        20 heads
# Shared heads: 7

# %% [markdown]
# ---
# ## Section 3 -- Core Ablation Infrastructure

# %%
class HeadAblationHooks:
    """Context manager that zeros out selected attention heads before o_proj."""

    def __init__(self, model, heads: list[tuple[int, int]]):
        self.model = model
        self.heads = heads
        self.handles = []
        self.head_dim = model.config.hidden_size // model.config.num_attention_heads

        # Group heads by layer for efficient hooking
        self.by_layer = {}
        for layer_idx, head_idx in heads:
            self.by_layer.setdefault(layer_idx, set()).add(head_idx)

    def __enter__(self):
        for layer_idx, layer_heads in self.by_layer.items():
            if layer_idx >= len(self.model.model.layers):
                continue
            o_proj = self.model.model.layers[layer_idx].self_attn.o_proj

            def pre_hook(_module, inputs, heads=sorted(layer_heads)):
                x = inputs[0]
                if x.ndim != 3:
                    return inputs
                x = x.clone()
                for head_idx in heads:
                    start = head_idx * self.head_dim
                    end = start + self.head_dim
                    x[..., start:end] = 0
                return (x,)

            self.handles.append(o_proj.register_forward_pre_hook(pre_hook))
        return self

    def __exit__(self, exc_type, exc_val, exc_tb):
        for handle in self.handles:
            handle.remove()
        self.handles = []

# %%
def greedy_decode(model, tokenizer, prompt_ids, max_tokens=MAX_DECODE_TOKENS) -> str:
    """Prefill + token-by-token greedy decode. No attention output needed."""
    with torch.inference_mode():
        out = model(
            input_ids=prompt_ids[:, :-1],
            use_cache=True,
            return_dict=True,
            output_attentions=False,
        )
        past_kv = out.past_key_values
        inp = prompt_ids[:, -1:]
        position = prompt_ids.size(1) - 1
        device = prompt_ids.device

        generated = []
        for _ in range(max_tokens):
            pos_ids = torch.tensor([[position]], dtype=torch.long, device=device)
            out = model(
                input_ids=inp,
                past_key_values=past_kv,
                position_ids=pos_ids,
                use_cache=True,
                output_attentions=False,
                return_dict=True,
            )
            past_kv = out.past_key_values
            next_id = out.logits[:, -1].argmax(dim=-1)
            generated.append(next_id.item())
            if next_id.item() == tokenizer.eos_token_id:
                break
            position += 1
            inp = next_id.unsqueeze(1)

    return tokenizer.decode(generated, skip_special_tokens=True).strip()

# %%
def normalize_value(text: str) -> str:
    """Lowercase, strip whitespace, remove commas, convert number words to digits."""
    if not text:
        return ""
    s = re.sub(r"\s+", " ", str(text).replace("\n", " ")).strip().lower()
    s = s.replace(",", "")

    number_words = {
        "zero": "0", "one": "1", "two": "2", "three": "3", "four": "4",
        "five": "5", "six": "6", "seven": "7", "eight": "8", "nine": "9",
        "ten": "10", "eleven": "11", "twelve": "12", "thirteen": "13",
        "fourteen": "14", "fifteen": "15", "sixteen": "16", "seventeen": "17",
        "eighteen": "18", "nineteen": "19", "twenty": "20", "thirty": "30",
        "forty": "40", "fifty": "50", "sixty": "60", "seventy": "70",
        "eighty": "80", "ninety": "90",
    }
    for word, digit in number_words.items():
        s = re.sub(r"\b" + word + r"\b", digit, s)
    return s

# %% [markdown]
# ---
# ## Section 4 -- Prompt Building & Evaluation Helpers

# %%
CONTROL_TOKENS = ["<|begin_of_text|>", "<|end_of_text|>", "<|eot_id|>", "<|start_header_id|>", "<|end_header_id|>"]
TOKEN_PATTERN = re.compile("|".join(re.escape(t) for t in CONTROL_TOKENS))


def find_needle_span(
    prompt_ids: list[int],
    needle_ids: list[int],
    threshold: float = 0.9,
) -> tuple[int, int]:
    """Locate needle tokens inside the full tokenized prompt via sliding window overlap."""
    span_len = len(needle_ids)
    if span_len == 0:
        return -1, -1

    needle_set = set(needle_ids)

    for i in range(len(prompt_ids) - span_len + 1):
        window = set(prompt_ids[i : i + span_len])
        if len(window & needle_set) / len(needle_set) >= threshold:
            return i, i + span_len

    return -1, -1


def build_prompt(row: pd.Series, task: dict, tokenizer) -> dict:
    """Construct the prompt with needle inserted at NEEDLE_DEPTH and locate the needle span."""
    haystack = TOKEN_PATTERN.sub("", row["haystack_text"]).strip()
    needle = row["needle_sentence"]

    mid = len(haystack) // 2
    context = haystack[:mid] + " " + needle + " " + haystack[mid:]

    message = f"<document>{context}</document>\nQuestion: {task['question']}\nAnswer:"
    messages = [{"role": "user", "content": message}]

    encoded = tokenizer.apply_chat_template(
        messages,
        add_generation_prompt=True,
        tokenize=True,
        return_dict=True,
        return_tensors="pt",
    )
    input_ids = encoded["input_ids"]

    # Locate needle span in the tokenized prompt
    needle_ids = tokenizer.encode(needle, add_special_tokens=False)
    needle_start, needle_end = find_needle_span(input_ids[0].tolist(), needle_ids)

    return {
        "input_ids": input_ids,
        "needle_start": needle_start,
        "needle_end": needle_end,
    }

# %%
def evaluate_sample(model, tokenizer, row, task, ablation_heads=None) -> dict:
    """Build prompt, optionally ablate heads, greedy decode, score."""
    prompt = build_prompt(row, task, tokenizer)

    if prompt["needle_start"] == -1:
        return {"decoded": "", "value_match": False, "skipped": True}

    input_ids = prompt["input_ids"].to(model.device)
    hook_ctx = HeadAblationHooks(model, ablation_heads) if ablation_heads else nullcontext()

    with hook_ctx:
        decoded = greedy_decode(model, tokenizer, input_ids)

    ground_truth = row["needle_value"]
    value_match = normalize_value(ground_truth) in normalize_value(decoded)

    del input_ids
    torch.cuda.empty_cache()

    return {"decoded": decoded, "value_match": value_match, "skipped": False}

# %%
def evaluate_condition(
    model,
    tokenizer,
    eval_df: pd.DataFrame,
    condition_name: str,
    ablation_heads=None,
) -> dict:
    """Run evaluation on all rows in eval_df. Returns per-task accuracy dict."""
    results = {}
    total = len(eval_df)

    for i, (_, row) in enumerate(eval_df.iterrows(), start=1):
        if pd.isna(row["haystack_text"]) or pd.isna(row["needle_sentence"]):
            print(f"[{condition_name}] {i}/{total} SKIP — missing text data")
            continue

        task_id = row["task"]
        task = TASK_MAP[task_id]

        if task_id not in results:
            results[task_id] = {"attempts": 0, "matches": 0, "samples": []}

        sample_result = evaluate_sample(model, tokenizer, row, task, ablation_heads)

        if sample_result["skipped"]:
            continue

        results[task_id]["attempts"] += 1
        if sample_result["value_match"]:
            results[task_id]["matches"] += 1
        results[task_id]["samples"].append(sample_result)

        if i % 10 == 0:
            print(f"[{condition_name}] {i}/{total}")

    # Compute accuracy per task
    for task_id in results:
        r = results[task_id]
        r["accuracy"] = r["matches"] / max(1, r["attempts"])

    return results

# %% [markdown]
# ---
# ## Section 5 -- Experiment 1: Baseline Evaluation (No Ablation)

# %%
os.makedirs(ABLATION_OUTPUT_DIR, exist_ok=True)

baseline_results = evaluate_condition(model, tokenizer, ablation_df, "baseline")

print("\nBaseline results:")
for task_id, r in baseline_results.items():
    print(f"  {task_id:<35} {r['matches']}/{r['attempts']}  ({r['accuracy']:.1%})")
# Out:
# [baseline] 10/265
# [baseline] 20/265
# [baseline] 30/265
# [baseline] 50/265
# [baseline] 60/265
# [baseline] 70/265
# [baseline] 80/265
# [baseline] 90/265
# [baseline] 100/265
# [baseline] 110/265
# [baseline] 120/265
# [baseline] 130/265
# [baseline] 140/265
# [baseline] 150/265
# [baseline] 160/265
# [baseline] 180/265
# [baseline] 190/265
# [baseline] 200/265
# [baseline] 210/265
# [baseline] 220/265
# [baseline] 230/265
# [baseline] 240/265
# [baseline] 250/265
# [baseline] 260/265
#
# Baseline results:
#   employees_count_total               14/28  (50.0%)
#   incorporation_year                  22/31  (71.0%)
#   registrant_name                     36/39  (92.3%)
#   headquarters_city                   22/29  (75.9%)
#   ceo_lastname                        23/31  (74.2%)
#   headquarters_state                  21/27  (77.8%)
#   incorporation_state                 24/31  (77.4%)
#   holder_record_amount                5/29  (17.2%)
#   employees_count_full_time           6/10  (60.0%)

# %%
with open(os.path.join(ABLATION_OUTPUT_DIR, "baseline_results.json"), "w") as f:
    # Strip sample-level decoded text for cleaner JSON
    export = {tid: {"attempts": r["attempts"], "matches": r["matches"], "accuracy": r["accuracy"]} for tid, r in baseline_results.items()}
    json.dump(export, f, indent=2)
    print(f"Saved baseline results.")
# Out:
# Saved baseline results.

# %% [markdown]
# ---
# ## Section 6 -- Experiment 2: Within-Task Ablation

# %% [markdown]
# For each task, ablate that task's own top-K heads at increasing K values.

# %%
within_task_results = {}

for task_id in TASK_MAP:
    task_df = ablation_df[ablation_df["task"] == task_id].reset_index(drop=True)
    if len(task_df) == 0:
        print(f"SKIP {task_id} -- no ablation samples")
        continue

    available_heads = task_head_rankings.get(task_id, [])
    if not available_heads:
        print(f"SKIP {task_id} -- no ranked heads")
        continue

    within_task_results[task_id] = {}

    for k in ABLATION_K_VALUES:
        heads_to_ablate = available_heads[:k]
        if not heads_to_ablate:
            break

        condition_name = f"within_{task_id}_k{k}"
        results = evaluate_condition(model, tokenizer, task_df, condition_name, ablation_heads=heads_to_ablate)

        r = results.get(task_id, {"attempts": 0, "matches": 0, "accuracy": 0.0})
        within_task_results[task_id][k] = {
            "k": k,
            "heads_ablated": len(heads_to_ablate),
            "attempts": r["attempts"],
            "matches": r["matches"],
            "accuracy": r["accuracy"],
        }

        print(f"  {task_id} k={k}: {r['matches']}/{r['attempts']}  ({r['accuracy']:.1%})")
# Out:
# [within_registrant_name_k1] 10/42
# [within_registrant_name_k1] 20/42
# [within_registrant_name_k1] 30/42
# [within_registrant_name_k1] 40/42
#   registrant_name k=1: 34/39  (87.2%)
# [within_registrant_name_k2] 10/42
# [within_registrant_name_k2] 20/42
# [within_registrant_name_k2] 30/42
# [within_registrant_name_k2] 40/42
#   registrant_name k=2: 34/39  (87.2%)
# [within_registrant_name_k5] 10/42
# [within_registrant_name_k5] 20/42
# [within_registrant_name_k5] 30/42
# [within_registrant_name_k5] 40/42
#   registrant_name k=5: 32/39  (82.1%)
# [within_registrant_name_k10] 10/42
# [within_registrant_name_k10] 20/42
# [within_registrant_name_k10] 30/42
# [within_registrant_name_k10] 40/42
#   registrant_name k=10: 31/39  (79.5%)
# [within_registrant_name_k20] 10/42
# [within_registrant_name_k20] 20/42
# [within_registrant_name_k20] 30/42
# [within_registrant_name_k20] 40/42
#   registrant_name k=20: 32/39  (82.1%)
# [within_registrant_name_k30] 10/42
# [within_registrant_name_k30] 20/42
# [within_registrant_name_k30] 30/42
# [within_registrant_name_k30] 40/42
#   registrant_name k=30: 32/39  (82.1%)
# [within_registrant_name_k40] 10/42
# [within_registrant_name_k40] 20/42
# [within_registrant_name_k40] 30/42
# [within_registrant_name_k40] 40/42
#   registrant_name k=40: 32/39  (82.1%)
# [within_registrant_name_k50] 10/42
# [within_registrant_name_k50] 20/42
# [within_registrant_name_k50] 30/42
# [within_registrant_name_k50] 40/42
#   registrant_name k=50: 32/39  (82.1%)
# [within_headquarters_city_k1] 10/29
# [within_headquarters_city_k1] 20/29
#   headquarters_city k=1: 23/29  (79.3%)
# [within_headquarters_city_k2] 10/29
# [within_headquarters_city_k2] 20/29
#   headquarters_city k=2: 23/29  (79.3%)
# [within_headquarters_city_k5] 10/29
# [within_headquarters_city_k5] 20/29
#   headquarters_city k=5: 24/29  (82.8%)
# [within_headquarters_city_k10] 10/29
# [within_headquarters_city_k10] 20/29
#   headquarters_city k=10: 24/29  (82.8%)
# [within_headquarters_city_k20] 10/29
# [within_headquarters_city_k20] 20/29
#   headquarters_city k=20: 20/29  (69.0%)
# [within_headquarters_city_k30] 10/29
# [within_headquarters_city_k30] 20/29
#   headquarters_city k=30: 20/29  (69.0%)
# [within_headquarters_city_k40] 10/29
# [within_headquarters_city_k40] 20/29
#   headquarters_city k=40: 20/29  (69.0%)
# [within_headquarters_city_k50] 10/29
# [within_headquarters_city_k50] 20/29
#   headquarters_city k=50: 20/29  (69.0%)
# [within_headquarters_state_k1] 10/28
# [within_headquarters_state_k1] 20/28
#   headquarters_state k=1: 23/27  (85.2%)
# [within_headquarters_state_k2] 10/28
# [within_headquarters_state_k2] 20/28
#   headquarters_state k=2: 22/27  (81.5%)
# [within_headquarters_state_k5] 10/28
# [within_headquarters_state_k5] 20/28
#   headquarters_state k=5: 23/27  (85.2%)
# [within_headquarters_state_k10] 10/28
# [within_headquarters_state_k10] 20/28
#   headquarters_state k=10: 23/27  (85.2%)
# [within_headquarters_state_k20] 10/28
# [within_headquarters_state_k20] 20/28
#   headquarters_state k=20: 21/27  (77.8%)
# [within_headquarters_state_k30] 10/28
# [within_headquarters_state_k30] 20/28
#   headquarters_state k=30: 21/27  (77.8%)
# [within_headquarters_state_k40] 10/28
# [within_headquarters_state_k40] 20/28
#   headquarters_state k=40: 21/27  (77.8%)
# [within_headquarters_state_k50] 10/28
# [within_headquarters_state_k50] 20/28
#   headquarters_state k=50: 21/27  (77.8%)
# [within_incorporation_state_k1] 10/32
# [within_incorporation_state_k1] 20/32
# [within_incorporation_state_k1] 30/32
#   incorporation_state k=1: 26/31  (83.9%)
# [within_incorporation_state_k2] 10/32
# [within_incorporation_state_k2] 20/32
# [within_incorporation_state_k2] 30/32
#   incorporation_state k=2: 26/31  (83.9%)
# [within_incorporation_state_k5] 10/32
# [within_incorporation_state_k5] 20/32
# [within_incorporation_state_k5] 30/32
#   incorporation_state k=5: 26/31  (83.9%)
# [within_incorporation_state_k10] 10/32
# [within_incorporation_state_k10] 20/32
# [within_incorporation_state_k10] 30/32
#   incorporation_state k=10: 26/31  (83.9%)
# [within_incorporation_state_k20] 10/32
# [within_incorporation_state_k20] 20/32
# [within_incorporation_state_k20] 30/32
#   incorporation_state k=20: 27/31  (87.1%)
# [within_incorporation_state_k30] 10/32
# [within_incorporation_state_k30] 20/32
# [within_incorporation_state_k30] 30/32
#   incorporation_state k=30: 27/31  (87.1%)
# [within_incorporation_state_k40] 10/32
# [within_incorporation_state_k40] 20/32
# [within_incorporation_state_k40] 30/32
#   incorporation_state k=40: 27/31  (87.1%)
# [within_incorporation_state_k50] 10/32
# [within_incorporation_state_k50] 20/32
# [within_incorporation_state_k50] 30/32
#   incorporation_state k=50: 27/31  (87.1%)
# [within_incorporation_year_k1] 10/32
# [within_incorporation_year_k1] 20/32
# [within_incorporation_year_k1] 30/32
#   incorporation_year k=1: 19/31  (61.3%)
# [within_incorporation_year_k2] 10/32
# [within_incorporation_year_k2] 20/32
# [within_incorporation_year_k2] 30/32
#   incorporation_year k=2: 20/31  (64.5%)
# [within_incorporation_year_k5] 10/32
# [within_incorporation_year_k5] 20/32
# [within_incorporation_year_k5] 30/32
#   incorporation_year k=5: 22/31  (71.0%)
# [within_incorporation_year_k10] 10/32
# [within_incorporation_year_k10] 20/32
# [within_incorporation_year_k10] 30/32
#   incorporation_year k=10: 22/31  (71.0%)
# [within_incorporation_year_k20] 10/32
# [within_incorporation_year_k20] 20/32
# [within_incorporation_year_k20] 30/32
#   incorporation_year k=20: 20/31  (64.5%)
# [within_incorporation_year_k30] 10/32
# [within_incorporation_year_k30] 20/32
# [within_incorporation_year_k30] 30/32
#   incorporation_year k=30: 20/31  (64.5%)
# [within_incorporation_year_k40] 10/32
# [within_incorporation_year_k40] 20/32
# [within_incorporation_year_k40] 30/32
#   incorporation_year k=40: 20/31  (64.5%)
# [within_incorporation_year_k50] 10/32
# [within_incorporation_year_k50] 20/32
# [within_incorporation_year_k50] 30/32
#   incorporation_year k=50: 20/31  (64.5%)
# [within_employees_count_total_k1] 10/29
# [within_employees_count_total_k1] 20/29
#   employees_count_total k=1: 16/28  (57.1%)
# [within_employees_count_total_k2] 10/29
# [within_employees_count_total_k2] 20/29
#   employees_count_total k=2: 16/28  (57.1%)
# [within_employees_count_total_k5] 10/29
# [within_employees_count_total_k5] 20/29
#   employees_count_total k=5: 17/28  (60.7%)
# [within_employees_count_total_k10] 10/29
# [within_employees_count_total_k10] 20/29
#   employees_count_total k=10: 25/28  (89.3%)
# [within_employees_count_total_k20] 10/29
# [within_employees_count_total_k20] 20/29
#   employees_count_total k=20: 13/28  (46.4%)
# [within_employees_count_total_k30] 10/29
# [within_employees_count_total_k30] 20/29
#   employees_count_total k=30: 13/28  (46.4%)
# [within_employees_count_total_k40] 10/29
# [within_employees_count_total_k40] 20/29
#   employees_count_total k=40: 13/28  (46.4%)
# [within_employees_count_total_k50] 10/29
# [within_employees_count_total_k50] 20/29
#   employees_count_total k=50: 13/28  (46.4%)
# [within_holder_record_amount_k1] 10/29
# [within_holder_record_amount_k1] 20/29
#   holder_record_amount k=1: 3/29  (10.3%)
# [within_holder_record_amount_k2] 10/29
# [within_holder_record_amount_k2] 20/29
#   holder_record_amount k=2: 4/29  (13.8%)
# [within_holder_record_amount_k5] 10/29
# [within_holder_record_amount_k5] 20/29
#   holder_record_amount k=5: 1/29  (3.4%)
# [within_holder_record_amount_k10] 10/29
# [within_holder_record_amount_k10] 20/29
#   holder_record_amount k=10: 0/29  (0.0%)
# [within_holder_record_amount_k20] 10/29
# [within_holder_record_amount_k20] 20/29
#   holder_record_amount k=20: 0/29  (0.0%)
# [within_holder_record_amount_k30] 10/29
# [within_holder_record_amount_k30] 20/29
#   holder_record_amount k=30: 0/29  (0.0%)
# [within_holder_record_amount_k40] 10/29
# [within_holder_record_amount_k40] 20/29
#   holder_record_amount k=40: 0/29  (0.0%)
# [within_holder_record_amount_k50] 10/29
# [within_holder_record_amount_k50] 20/29
#   holder_record_amount k=50: 0/29  (0.0%)
# [within_employees_count_full_time_k1] 10/10
#   employees_count_full_time k=1: 6/10  (60.0%)
# [within_employees_count_full_time_k2] 10/10
#   employees_count_full_time k=2: 5/10  (50.0%)
# [within_employees_count_full_time_k5] 10/10
#   employees_count_full_time k=5: 5/10  (50.0%)
# [within_employees_count_full_time_k10] 10/10
#   employees_count_full_time k=10: 8/10  (80.0%)
# [within_employees_count_full_time_k20] 10/10
#   employees_count_full_time k=20: 6/10  (60.0%)
# [within_employees_count_full_time_k30] 10/10
#   employees_count_full_time k=30: 6/10  (60.0%)
# [within_employees_count_full_time_k40] 10/10
#   employees_count_full_time k=40: 6/10  (60.0%)
# [within_employees_count_full_time_k50] 10/10
#   employees_count_full_time k=50: 6/10  (60.0%)
# [within_ceo_lastname_k1] 10/34
# [within_ceo_lastname_k1] 20/34
# [within_ceo_lastname_k1] 30/34
#   ceo_lastname k=1: 23/31  (74.2%)
# [within_ceo_lastname_k2] 10/34
# [within_ceo_lastname_k2] 20/34
# [within_ceo_lastname_k2] 30/34
#   ceo_lastname k=2: 23/31  (74.2%)
# [within_ceo_lastname_k5] 10/34
# [within_ceo_lastname_k5] 20/34
# [within_ceo_lastname_k5] 30/34
#   ceo_lastname k=5: 23/31  (74.2%)
# [within_ceo_lastname_k10] 10/34
# [within_ceo_lastname_k10] 20/34
# [within_ceo_lastname_k10] 30/34
#   ceo_lastname k=10: 18/31  (58.1%)
# [within_ceo_lastname_k20] 10/34
# [within_ceo_lastname_k20] 20/34
# [within_ceo_lastname_k20] 30/34
#   ceo_lastname k=20: 16/31  (51.6%)
# [within_ceo_lastname_k30] 10/34
# [within_ceo_lastname_k30] 20/34
# [within_ceo_lastname_k30] 30/34
#   ceo_lastname k=30: 16/31  (51.6%)
# [within_ceo_lastname_k40] 10/34
# [within_ceo_lastname_k40] 20/34
# [within_ceo_lastname_k40] 30/34
#   ceo_lastname k=40: 16/31  (51.6%)
# [within_ceo_lastname_k50] 10/34
# [within_ceo_lastname_k50] 20/34
# [within_ceo_lastname_k50] 30/34
#   ceo_lastname k=50: 16/31  (51.6%)

# %%
with open(os.path.join(ABLATION_OUTPUT_DIR, "within_task_ablation.json"), "w") as f:
    json.dump(within_task_results, f, indent=2)
    print("Saved within-task ablation results.")
# Out:
# Saved within-task ablation results.

# %% [markdown]
# ---
# ## Section 7 -- Experiment 3: Across-Task Ablation (Shared Heads)

# %% [markdown]
# Ablate the global shared retrieval heads and measure accuracy across all tasks.

# %%
across_task_results = {}

for k in ABLATION_K_VALUES:
    heads_to_ablate = shared_heads[:k]
    if not heads_to_ablate:
        print(f"Only {len(shared_heads)} shared heads available, stopping at k={k}")
        break

    condition_name = f"across_task_k{k}"
    results = evaluate_condition(model, tokenizer, ablation_df, condition_name, ablation_heads=heads_to_ablate)

    total_attempts = sum(r["attempts"] for r in results.values())
)

# %%
with open(os.path.join(ABLATION_OUTPUT_DIR, "across_task_ablation.json"), "w") as f:
    json.dump(across_task_results, f, indent=2)
    print("Saved across-task ablation results.")
# Out:
# Saved across-task ablation results.

# %% [markdown]
# ---
# ## Section 8 -- Random Head Ablation Control

# %% [markdown]
# Ablate randomly selected heads to prove the accuracy drop is specific to retrieval heads.

# %%
num_layers = model.config.num_hidden_layers
num_heads = model.config.num_attention_heads

# All possible (layer, head) pairs, excluding the shared retrieval heads
shared_set = set(shared_heads)
all_heads = [(l, h) for l in range(num_layers) for h in range(num_heads) if (l, h) not in shared_set]

random.seed(SPLIT_SEED)
random_pool = random.sample(all_heads, min(max(ABLATION_K_VALUES), len(all_heads)))

random_ablation_results = {}

for k in ABLATION_K_VALUES:
    heads_to_ablate = random_pool[:k]

    condition_name = f"random_k{k}"
    results = evaluate_condition(model, tokenizer, ablation_df, condition_name, ablation_heads=heads_to_ablate)

    total_attempts = sum(r["attempts"] for r in results.values())
    total_matches  = sum(r["matches"] for r in results.values())
    overall_acc    = total_matches / max(1, total_attempts)

    random_ablation_results[k] = {
        "k": k,
        "heads_ablated": [(l, h) for l, h in heads_to_ablate],
        "overall_accuracy": overall_acc,
        "total_attempts": total_attempts,
        "total_matches": total_matches,
    }

    print(f"random k={k}: {total_matches}/{total_attempts}  ({overall_acc:.1%})")
# Out:
# [random_k1] 10/265
# [random_k1] 20/265
# [random_k1] 30/265
# [random_k1] 50/265
# [random_k1] 60/265
# [random_k1] 70/265
# [random_k1] 80/265
# [random_k1] 90/265
# [random_k1] 100/265
# [random_k1] 110/265
# [random_k1] 120/265
# [random_k1] 130/265
# [random_k1] 140/265
# [random_k1] 150/265
# [random_k1] 160/265
# [random_k1] 180/265
# [random_k1] 190/265
# [random_k1] 200/265
# [random_k1] 210/265
# [random_k1] 220/265
# [random_k1] 230/265
# [random_k1] 240/265
# [random_k1] 250/265
# [random_k1] 260/265
# random k=1: 175/255  (68.6%)
# [random_k2] 10/265
# [random_k2] 20/265
# [random_k2] 30/265
# [random_k2] 50/265
# [random_k2] 60/265
# [random_k2] 70/265
# [random_k2] 80/265
# [random_k2] 90/265
# [random_k2] 100/265
# [random_k2] 110/265
# [random_k2] 120/265
# [random_k2] 130/265
# [random_k2] 140/265
# [random_k2] 150/265
# [random_k2] 160/265
# [random_k2] 180/265
# [random_k2] 190/265
# [random_k2] 200/265
# [random_k2] 210/265
# [random_k2] 220/265
# [random_k2] 230/265
# [random_k2] 240/265
# [random_k2] 250/265
# [random_k2] 260/265
# random k=2: 174/255  (68.2%)
# [random_k5] 10/265
# [random_k5] 20/265
# [random_k5] 30/265
# [random_k5] 50/265
# [random_k5] 60/265
# [random_k5] 70/265
# [random_k5] 80/265
# [random_k5] 90/265
# [random_k5] 100/265
# [random_k5] 110/265
# [random_k5] 120/265
# [random_k5] 130/265
# [random_k5] 140/265
# [random_k5] 150/265
# [random_k5] 160/265
# [random_k5] 180/265
# [random_k5] 190/265
# [random_k5] 200/265
# [random_k5] 210/265
# [random_k5] 220/265
# [random_k5] 230/265
# [random_k5] 240/265
# [random_k5] 250/265
# [random_k5] 260/265
# random k=5: 180/255  (70.6%)
# [random_k10] 10/265
# [random_k10] 20/265
    json.dump(random_ablation_results, f, indent=2)
    print("Saved random ablation control results.")
# Out:
# Saved random ablation control results.

# %% [markdown]
# #### I can't believe I forgot that I only had the top 20 heads ranked explictly ranked

# %%
within_path = os.path.join(ABLATION_OUTPUT_DIR, "within_task_ablation.json")
if os.path.exists(within_path):
    with open(within_path, "r") as f:
        within_data = json.load(f)

    for task_id in within_data:
        # Delete keys '30', '40', '50'
        for k in ["30", "40", "50"]:
            within_data[task_id].pop(k, None)

    with open(within_path, "w") as f:
        json.dump(within_data, f, indent=2)

# Clean up Across-Task
across_path = os.path.join(ABLATION_OUTPUT_DIR, "across_task_ablation.json")
if os.path.exists(across_path):
    with open(across_path, "r") as f:
        across_data = json.load(f)

    for k in ["30", "40", "50"]:
        across_data.pop(k, None)

    with open(across_path, "w") as f:
        json.dump(across_data, f, indent=2)

# Clean up Random Control
random_path = os.path.join(ABLATION_OUTPUT_DIR, "random_ablation_control.json")
if os.path.exists(random_path):
    with open(random_path, "r") as f:
        random_data = json.load(f)

    for k in ["30", "40", "50"]:
        random_data.pop(k, None)

    with open(random_path, "w") as f:
        json.dump(random_data, f, indent=2)

print("Cleaned up JSON files! Removed invalid K>20 results.")
# Out:
# Cleaned up JSON files! Removed invalid K>20 results.

# %%
ABLATION_K_VALUES = [1, 2, 5, 10, 20]

# %% [markdown]
# ---
# ## Section 9 -- Visualizations

# %%
# Baseline accuracy per task
baseline_acc = {tid: r["accuracy"] for tid, r in baseline_results.items()}
baseline_overall = sum(r["matches"] for r in baseline_results.values()) / max(1, sum(r["attempts"] for r in baseline_results.values()))

print(f"Baseline overall accuracy: {baseline_overall:.1%}")
# Out:
# Baseline overall accuracy: 67.8%

# %% [markdown]
# ##### Chart 1: Across-task ablation vs random ablation

# %%
fig, ax = plt.subplots(figsize=(10, 6))

target_k = ABLATION_K_VALUES

# Filter to ensure we only plot the desired K values
k_vals = sorted([k for k in across_task_results.keys() if k in target_k])
retrieval_acc = [across_task_results[k]["overall_accuracy"] for k in k_vals]
random_acc = [random_ablation_results[k]["overall_accuracy"] for k in k_vals if k in random_ablation_results]

ax.axhline(y=baseline_overall, color="green", linestyle="--", label="Baseline")
ax.plot(k_vals, retrieval_acc, "ro-", label="Retrieval heads ablated")
ax.plot(k_vals[:len(random_acc)], random_acc, "bs-", label="Random heads ablated")

ax.set_xlabel("Number of heads ablated (K)")
ax.set_ylabel("Accuracy")
ax.set_title("Shared Retrieval Head Ablation vs Random Control")
ax.legend()
ax.set_ylim(0, 1.05)

# Explicitly set the x-ticks
ax.set_xticks(target_k)

plt.tight_layout()
fig_path = os.path.join(ABLATION_OUTPUT_DIR, "across_task_vs_random.png")
plt.savefig(fig_path, dpi=150)
plt.show()
print(f"Saved: {fig_path}")
# Out:
# Saved: //ablation_results/across_task_vs_random.png

# %% [markdown]
# ##### Chart 2: Within-task ablation per task

# %%
fig, ax = plt.subplots(figsize=(12, 6))

target_k = ABLATION_K_VALUES

for task_id, k_results in within_task_results.items():

    # Filter to only the desired K values
    k_vals = sorted([k for k in k_results if k in target_k])
    acc_vals = [k_results[k]["accuracy"] for k in k_vals]

    ax.plot(k_vals, acc_vals, "o-", label=task_id)

ax.axhline(y=baseline_overall, color="green", linestyle="--", label="Baseline (overall)")

ax.set_xlabel("Number of heads ablated (K)")
ax.set_ylabel("Accuracy")

# Explicitly set the x-ticks
ax.set_xticks(target_k)

ax.set_title("Within-Task Ablation: Accuracy vs K")
ax.legend(bbox_to_anchor=(1.05, 1), loc="upper left", fontsize=8)
ax.set_ylim(0, 1.05)

plt.tight_layout()
fig_path = os.path.join(ABLATION_OUTPUT_DIR, "within_task_ablation.png")
plt.savefig(fig_path, dpi=150, bbox_inches="tight")
plt.show()
print(f"Saved: {fig_path}")
# Out:
# Saved: //ablation_results/within_task_ablation.png

# %% [markdown]
# #### Accuracy drop per task at increasing K values

# %%
max_k = max(ABLATION_K_VALUES)
task_drops = []
task_labels = []

clean_names = {
    'registrant_name': 'Reg. Name', 'headquarters_city': 'HQ City',
    'headquarters_state': 'HQ State', 'incorporation_state': 'Inc. State',
    'incorporation_year': 'Inc. Year', 'employees_count_total': 'Emp. Total',
    'holder_record_amount': 'Stock Holders', 'employees_count_full_time': 'Emp. Full-Time',
    'ceo_lastname': 'CEO Name'
}

for task_id, results in within_task_results.items():
    if max_k in results:
        base_acc = baseline_results[task_id]['accuracy']
        ablated_acc = results[max_k]['accuracy']
        task_drops.append((base_acc - ablated_acc) * 100)
        task_labels.append(clean_names.get(task_id, task_id))

# Sort by largest drop
sorted_idx = np.argsort(task_drops)[::-1]
task_drops = np.array(task_drops)[sorted_idx]
task_labels = np.array(task_labels)[sorted_idx]

plt.figure(figsize=(10, 6))
bars = plt.bar(task_labels, task_drops, color='steelblue')

plt.ylabel("Accuracy Drop (%)")
plt.title(f"Impact of Ablating Top {max_k} Heads (Comparison at K={max_k})")
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', linestyle='--', alpha=0.5)

for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 1, f'{yval:.1f}%', ha='center', va='bottom')

plt.tight_layout()
plt.savefig(os.path.join(ABLATION_OUTPUT_DIR, "accuracy_drop_summary.png"), dpi=150)
plt.show()

# %% [markdown]
# ##### Summary table

# %%
summary_rows = []

# Ensure we only summarize the relevant K values
for k in sorted(ABLATION_K_VALUES):
    if k in across_task_results:
        retrieval = across_task_results[k]["overall_accuracy"]
        rand = random_ablation_results.get(k, {}).get("overall_accuracy", None)
        summary_rows.append({
            "k": k,
            "baseline": baseline_overall,
            "retrieval_ablated": retrieval,
            "random_ablated": rand,
            "delta_retrieval": retrieval - baseline_overall,
            "delta_random": (rand - baseline_overall) if rand else None,
        })

summary_df = pd.DataFrame(summary_rows)
print(summary_df.to_string(index=False))
# Out:
#  k  baseline  retrieval_ablated  random_ablated  delta_retrieval  delta_random
#  1  0.678431           0.678431        0.686275         0.000000      0.007843
#  2  0.678431           0.666667        0.682353        -0.011765      0.003922
#  5  0.678431           0.674510        0.705882        -0.003922      0.027451
# 10  0.678431           0.674510        0.682353        -0.003922      0.003922
# 20  0.678431           0.674510        0.709804        -0.003922      0.031373

# %%
import shutil
from google.colab import files

# Define the folder to zip and the output filename
folder_path = '/ablation_results'
output_filename = '/content/ablation_results'

# Create a zip archive
shutil.make_archive(output_filename, 'zip', folder_path)

# Download the zip file
files.download(output_filename + '.zip')
print(f"Zipped and downloading: {output_filename}.zip")
# Out:
# Zipped and downloading: /content/ablation_results.zip
